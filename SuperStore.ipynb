# %%
import pandas as pd
import matplotlib as plt

# %%
#sell.fillna(0)

sell = sell.fillna(0)

# %%
sell.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#              State        Country   Product ID     Sales  Quantity  Discount  \
# ...

# %%
sell['Order Date'].astype('str')
# Out:
# 0        2014-11-11
# 1        2014-02-05
# 2        2014-10-17
# 3        2014-01-28
# 4        2014-11-05
#             ...
# 51285    2015-06-19
# 51286    2014-05-06
# 51287    2012-08-26
# 51288    2013-02-17
# 51289    2013-05-22
# Name: Order Date, Length: 51290, dtype: object

# %%
sell.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 19 columns):
# Row ID            51290 non-null int64
# Order ID          51290 non-null object
# Order Date        51290 non-null datetime64[ns]
# Ship Date         51290 non-null datetime64[ns]
# Ship Mode         51290 non-null object
# Customer ID       51290 non-null object
# Customer Name     51290 non-null object
# Segment           51290 non-null object
# Postal Code       51290 non-null float64
# City              51290 non-null object
# State             51290 non-null object
# Country           51290 non-null object
# Product ID        51290 non-null object
# Sales             51290 non-null float64
# Quantity          51290 non-null int64
# Discount          51290 non-null float64
# Profit            51290 non-null float64
# Shipping Cost     51290 non-null float64
# Order Priority    51290 non-null object
# dtypes: datetime64[ns](2), float64(5), int64(2), object(10)
# ...

# %%
sell.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#              State        Country   Product ID     Sales  Quantity  Discount  \
# ...

# %%
sell.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#              State        Country   Product ID     Sales  Quantity  Discount  \
# ...

# %%
sell[sell['Segment'] == 'Consumer']
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# 6       30570   IN-2012-TS2134092-41219 2012-11-06 2012-11-08     First Class
# 7       31192   IN-2013-MB1808592-41378 2013-04-14 2013-04-18  Standard Class
# ...       ...                       ...        ...        ...             ...
# 51280   35112  CA-2014-ZD21925140-41829 2014-07-09 2014-07-09        Same Day
# 51281    6039   MX-2015-HG1502518-42164 2015-06-09 2015-06-11     First Class
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
sell[sell['State'] == 'Oklahoma']
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 8       40099  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 713     33927  CA-2013-AB10150140-41527 2013-09-10 2013-09-15  Standard Class
# 1505    37455  CA-2014-AG10330140-41855 2014-08-04 2014-08-06    Second Class
# 1518    37454  CA-2014-AG10330140-41855 2014-08-04 2014-08-06    Second Class
# ...       ...                       ...        ...        ...             ...
# 49987   33943  CA-2012-TB21400140-41158 2012-09-06 2012-09-11    Second Class
# 49990   33942  CA-2012-TB21400140-41158 2012-09-06 2012-09-11    Second Class
# 50001   33944  CA-2012-TB21400140-41158 2012-09-06 2012-09-11    Second Class
# 50073   36434  CA-2014-TS21430140-41957 2014-11-14 2014-11-18  Standard Class
# 50165   35839  CA-2015-TM21490140-42094 2015-03-31 2015-04-01     First Class
#
# ...

# %%
sell[sell['City'] == 'Tulsa']
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 713     33927  CA-2013-AB10150140-41527 2013-09-10 2013-09-15  Standard Class
# 1505    37455  CA-2014-AG10330140-41855 2014-08-04 2014-08-06    Second Class
# 1518    37454  CA-2014-AG10330140-41855 2014-08-04 2014-08-06    Second Class
# 2172    34270  CA-2015-AR10510140-42355 2015-12-17 2015-12-21  Standard Class
# 6255    33266  CA-2015-BD11320140-42271 2015-09-24 2015-09-30  Standard Class
# 12021   35725  CA-2015-CL12565140-42085 2015-03-22 2015-03-28  Standard Class
# 18302   40744  CA-2015-DN13690140-42152 2015-05-28 2015-06-04  Standard Class
# 24691   37718  CA-2014-HW14935140-41944 2014-11-01 2014-11-06  Standard Class
# 24716   37716  CA-2014-HW14935140-41944 2014-11-01 2014-11-06  Standard Class
# 24790   37717  CA-2014-HW14935140-41944 2014-11-01 2014-11-06  Standard Class
# 24821   37715  CA-2014-HW14935140-41944 2014-11-01 2014-11-06  Standard Class
# ...

# %%
mask = sell['State'] == 'Oklahoma'
sell[mask]
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 8       40099  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 713     33927  CA-2013-AB10150140-41527 2013-09-10 2013-09-15  Standard Class
# 1505    37455  CA-2014-AG10330140-41855 2014-08-04 2014-08-06    Second Class
# 1518    37454  CA-2014-AG10330140-41855 2014-08-04 2014-08-06    Second Class
# ...       ...                       ...        ...        ...             ...
# 49987   33943  CA-2012-TB21400140-41158 2012-09-06 2012-09-11    Second Class
# 49990   33942  CA-2012-TB21400140-41158 2012-09-06 2012-09-11    Second Class
# 50001   33944  CA-2012-TB21400140-41158 2012-09-06 2012-09-11    Second Class
# 50073   36434  CA-2014-TS21430140-41957 2014-11-14 2014-11-18  Standard Class
# 50165   35839  CA-2015-TM21490140-42094 2015-03-31 2015-04-01     First Class
#
# ...

# %%
sell[sell['Segment']=='Consumer'].head(5)
# Out:
#    Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# 6   30570   IN-2012-TS2134092-41219 2012-11-06 2012-11-08     First Class
# 7   31192   IN-2013-MB1808592-41378 2013-04-14 2013-04-18  Standard Class
#
#     Customer ID  Customer Name   Segment  Postal Code           City  \
# 0  AB-100151402  Aaron Bergman  Consumer      73120.0  Oklahoma City
# 2     CR-127307   Craig Reiter  Consumer          NaN       Brisbane
# 4    RH-9495111    Rick Hansen  Consumer          NaN          Dakar
# 6    TS-2134092  Toby Swindell  Consumer          NaN        Porirua
# 7    MB-1808592     Mick Brown  Consumer          NaN       Hamilton
#
#         State        Country   Product ID     Sales  Quantity  Discount  \
# ...

# %%
sell[sell['Segment'] != 'Consumer']
# Out:
#        Row ID                 Order ID Order Date  Ship Date       Ship Mode  \
# 1       26341   IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 3       13524  ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 5       22732   IN-2014-JM156557-41818 2014-06-28 2014-07-01    Second Class
# 11      28879   ID-2013-AJ107801-41383 2013-04-19 2013-04-22     First Class
# 13       4132  MX-2013-VF2171518-41591 2013-11-13 2013-11-13        Same Day
# ...       ...                      ...        ...        ...             ...
# 51282   24175   IN-2015-DB132707-42221 2015-08-05 2015-08-10  Standard Class
# 51283   24105  IN-2015-KH1633058-42154 2015-05-30 2015-05-30        Same Day
# 51284    9922  MX-2013-KM1637593-41636 2013-12-28 2013-12-31     First Class
# 51285   29002  IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51288    9596  MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
#
# ...

# %%
sell['Segment']
# Out:
# 0           Consumer
# 1          Corporate
# 2           Consumer
# 3        Home Office
# 4           Consumer
#             ...
# 51285      Corporate
# 51286       Consumer
# 51287       Consumer
# 51288    Home Office
# 51289       Consumer
# Name: Segment, Length: 51290, dtype: object

# %%
sell[sell['Sales'] > 7000]
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 17      12069   ES-2015-PJ1883564-42255 2015-09-08 2015-09-14  Standard Class
# 419     40336  CA-2014-AB10105140-41991 2014-12-18 2014-12-22  Standard Class
# 5326    31462  CA-2012-BM11140140-41159 2012-09-07 2012-09-11  Standard Class
# 6422    35574  US-2014-BS11365140-41746 2014-04-17 2014-04-21  Standard Class
# 11063   37722  CA-2014-CC12370140-41783 2014-05-24 2014-05-28  Standard Class
# 23110   31980  US-2015-GT14635140-42313 2015-11-05 2015-11-05        Same Day
# 25238   35487  CA-2015-HL15040140-42326 2015-11-18 2015-11-23  Standard Class
# 33757   33802  CA-2012-KL16645140-41114 2012-07-24 2012-07-26    Second Class
# 44248   39450  CA-2015-RB19360140-42087 2015-03-24 2015-03-26     First Class
# 46295   35395  CA-2012-SC20095140-41174 2012-09-22 2012-09-27  Standard Class
# 46386   39785  CA-2014-SE20110140-41672 2014-02-02 2014-02-04    Second Class
# ...

# %%
mask = sell['Order Date'] <= '2015-01-01'
sell[mask]
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51284    9922   MX-2013-KM1637593-41636 2013-12-28 2013-12-31     First Class
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
mask1 = sell['Segment'] == 'Consumer'

mask2 = sell['City'] =='Dakar'

sell[mask1 & mask2]
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# 2221    42700   SG-2014-BS1665111-41734 2014-04-05 2014-04-08     First Class
# 2999    42483   SG-2012-CD1980111-41020 2012-04-21 2012-04-22     First Class
# 4527    44368   SG-2014-RP9390111-41885 2014-09-03 2014-09-09  Standard Class
# 6133    50384   SG-2015-JH6180111-42158 2015-06-03 2015-06-07    Second Class
# 7651    50385   SG-2015-JH6180111-42158 2015-06-03 2015-06-07    Second Class
# 7664    49193  SG-2015-ZD11925111-42158 2015-06-03 2015-06-05    Second Class
# 8711    49194  SG-2015-ZD11925111-42158 2015-06-03 2015-06-05    Second Class
# 9659    49171   SG-2014-MM8055111-41767 2014-05-08 2014-05-14  Standard Class
# 9672    48162   SG-2014-DD3570111-41998 2014-12-25 2014-12-27    Second Class
# 10484   49192  SG-2015-ZD11925111-42158 2015-06-03 2015-06-05    Second Class
# ...

# %%
mask1 = sell['Segment'] == 'Consumer'
mask2 = sell['Order Date'] < '2015-01-01'

sell[mask1 | mask2]
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51284    9922   MX-2013-KM1637593-41636 2013-12-28 2013-12-31     First Class
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
#sell[sell['City'] == 'Managua']
# Out:
#        Row ID                 Order ID Order Date  Ship Date       Ship Mode  \
# 260      9857  MX-2015-KC1654093-42158 2015-06-03 2015-06-07  Standard Class
# 261      2398  MX-2015-CS1246093-42259 2015-09-12 2015-09-14     First Class
# 321      2397  MX-2015-CS1246093-42259 2015-09-12 2015-09-14     First Class
# 394      8295  MX-2015-CM1216093-42158 2015-06-03 2015-06-05     First Class
# 399      6826  MX-2012-HL1504093-40929 2012-01-21 2012-01-27  Standard Class
# ...       ...                      ...        ...        ...             ...
# 50024    7062  MX-2015-PK1891093-42256 2015-09-09 2015-09-12     First Class
# 50769    9920  MX-2013-KM1637593-41636 2013-12-28 2013-12-31     First Class
# 51090    7912  MX-2013-HG1502593-41532 2013-09-15 2013-09-16     First Class
# 51092    9285  MX-2014-MC1760593-41975 2014-12-02 2014-12-04    Second Class
# 51284    9922  MX-2013-KM1637593-41636 2013-12-28 2013-12-31     First Class
#
# ...

# %%
mask1 = sell['Segment'] == 'Consumer'
mask2 = sell['Order Date'] > '2015-01-01'

sell[mask1 & mask2]
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 19      49463   TZ-2015-RH9555129-42343 2015-12-05 2015-12-07    Second Class
# 24       1570   US-2015-NP1832582-42216 2015-07-31 2015-08-01     First Class
# 25       3484   MX-2015-VD2167039-42252 2015-09-05 2015-09-08     First Class
# 38      15380  ES-2015-PO18865139-42018 2015-01-14 2015-01-18  Standard Class
# 47      24341   IN-2015-AP1091527-42244 2015-08-28 2015-08-29     First Class
# ...       ...                       ...        ...        ...             ...
# 51267   39638  CA-2015-ZD21925140-42167 2015-06-12 2015-06-15     First Class
# 51268   47274   SA-2015-JW6075110-42103 2015-04-09 2015-04-13  Standard Class
# 51270   13800   ES-2015-NM1852045-42221 2015-08-05 2015-08-11  Standard Class
# 51272    5465   MX-2015-AA1048031-42111 2015-04-17 2015-04-20    Second Class
# 51281    6039   MX-2015-HG1502518-42164 2015-06-09 2015-06-11     First Class
#
# ...

# %%
mask = sell['Segment'].isin(['Consumer','Home Office'])


sell[mask]
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# 6       30570   IN-2012-TS2134092-41219 2012-11-06 2012-11-08     First Class
# ...       ...                       ...        ...        ...             ...
# 51284    9922   MX-2013-KM1637593-41636 2013-12-28 2013-12-31     First Class
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
sell.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#              State        Country   Product ID     Sales  Quantity  Discount  \
# ...

# %%
mask = sell['Postal Code'].isnull()


sell[mask]
# Out:
#        Row ID                 Order ID Order Date  Ship Date       Ship Mode  \
# 1       26341   IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330   IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524  ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221  SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# 5       22732   IN-2014-JM156557-41818 2014-06-28 2014-07-01    Second Class
# ...       ...                      ...        ...        ...             ...
# 51283   24105  IN-2015-KH1633058-42154 2015-05-30 2015-05-30        Same Day
# 51284    9922  MX-2013-KM1637593-41636 2013-12-28 2013-12-31     First Class
# 51285   29002  IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51288    9596  MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147  MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
sell['Postal Code'].notnull()
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286     True
# 51287     True
# 51288    False
# 51289    False
# Name: Postal Code, Length: 51290, dtype: bool

# %%
sell.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#              State        Country   Product ID     Sales  Quantity  Discount  \
# ...

# %%
mask = sell[sell['Postal Code'].notnull()]

mask['Postal Code'].count()
# Out:
# 9994

# %%
sell[sell['Sales'].between(20000, 80000)]
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 47114   33994  CA-2012-SM20320140-40985 2012-03-17 2012-03-22  Standard Class
#
#         Customer ID Customer Name      Segment  Postal Code          City  \
# 47114  SM-203201408   Sean Miller  Home Office      32216.0  Jacksonville
#
#          State        Country   Product ID     Sales  Quantity  Discount  \
# 47114  Florida  United States  TEC-MA-3819  22638.48         6       0.5
#
#           Profit  Shipping Cost Order Priority
# 47114 -1811.0784        24.2865         Medium

# %%
sell.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#              State        Country   Product ID     Sales  Quantity  Discount  \
# ...

# %%
a = sell['Segment'].isin(['Consumer','Corporate'])

sell[a].fillna(0)
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# 5       22732    IN-2014-JM156557-41818 2014-06-28 2014-07-01    Second Class
# ...       ...                       ...        ...        ...             ...
# 51283   24105   IN-2015-KH1633058-42154 2015-05-30 2015-05-30        Same Day
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
sell.head(3)
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
#
#     Customer ID  Customer Name    Segment  Postal Code           City  \
# 0  AB-100151402  Aaron Bergman   Consumer      73120.0  Oklahoma City
# 1     JR-162107  Justin Ritter  Corporate          NaN     Wollongong
# 2     CR-127307   Craig Reiter   Consumer          NaN       Brisbane
#
#              State        Country   Product ID     Sales  Quantity  Discount  \
# 0         Oklahoma  United States  TEC-PH-5816   221.980         2       0.0
# 1  New South Wales      Australia  FUR-CH-5379  3709.395         9       0.1
# 2       Queensland      Australia  TEC-PH-5356  5175.171         9       0.1
#
#      Profit  Shipping Cost Order Priority
# ...

# %%
sell[sell['Sales'].between(0,80000)]
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
sell[sell['Order Date'].between('2015-01-01','2015-12-31')]
# Out:
#        Row ID                 Order ID Order Date  Ship Date       Ship Mode  \
# 15      13779  ES-2015-BP1118545-42216 2015-07-31 2015-08-03    Second Class
# 17      12069  ES-2015-PJ1883564-42255 2015-09-08 2015-09-14  Standard Class
# 18      22096   IN-2015-JS156857-42035 2015-01-31 2015-02-01     First Class
# 19      49463  TZ-2015-RH9555129-42343 2015-12-05 2015-12-07    Second Class
# 24       1570  US-2015-NP1832582-42216 2015-07-31 2015-08-01     First Class
# ...       ...                      ...        ...        ...             ...
# 51277   46582  TU-2015-KF6285134-42337 2015-11-29 2015-11-30     First Class
# 51281    6039  MX-2015-HG1502518-42164 2015-06-09 2015-06-11     First Class
# 51282   24175   IN-2015-DB132707-42221 2015-08-05 2015-08-10  Standard Class
# 51283   24105  IN-2015-KH1633058-42154 2015-05-30 2015-05-30        Same Day
# 51285   29002  IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
#
# ...

# %%
sell['Order Date'].min()
# Out:
# Timestamp('2012-01-01 00:00:00')

# %%
sell['Order Date'].sort_values(ascending = True)
# Out:
# 22950   2012-01-01
# 43610   2012-01-01
# 25078   2012-01-01
# 31870   2012-01-01
# 31583   2012-01-01
#            ...
# 17379   2015-12-31
# 42870   2015-12-31
# 39873   2015-12-31
# 7908    2015-12-31
# 39602   2015-12-31
# Name: Order Date, Length: 51290, dtype: datetime64[ns]

# %%
sell['Country'].duplicated(keep = False)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 51285    True
# 51286    True
# 51287    True
# 51288    True
# 51289    True
# Name: Country, Length: 51290, dtype: bool

# %%
len(sell)
# Out:
# 51290

# %%
sell.drop_duplicates(subset = ['Country'], keep = 'last')
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 2881    41763   SA-2015-IG5085110-42133 2015-05-09 2015-05-11    Second Class
# 4803    49476    MZ-2015-KE642087-42118 2015-04-24 2015-04-26    Second Class
# 11914   44344   IV-2014-SG1047029-41951 2014-11-08 2014-11-10     First Class
# 18013    4212   MX-2015-MH1802518-42169 2015-06-14 2015-06-17     First Class
# 20198   22190   IN-2013-VM2168558-41298 2013-01-24 2013-01-30  Standard Class
# ...       ...                       ...        ...        ...             ...
# 51283   24105   IN-2015-KH1633058-42154 2015-05-30 2015-05-30        Same Day
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
sell.describe().astype('int')
# Out:
#        Row ID  Postal Code  Sales  Quantity  Discount  Profit  Shipping Cost
# count   51290         9994  51290     51290     51290   51290          51290
# mean    25645        55190    246         3         0      28             26
# std     14806        32063    487         2         0     174             57
# min         1         1040      0         1         0   -6599              1
# 25%     12823        23223     30         2         0       0              2
# 50%     25645        56430     85         3         0       9              7
# 75%     38467        90008    251         5         0      36             24
# max     51290        99301  22638        14         0    8399            933

# %%
sell[sell['Order Date'].between(sell['Order Date'].min(),sell['Order Date'].max())]
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
mask1 = sell[sell['Customer Name'] == 'Justin Ritter']

mask1['Order Date'].min()
# Out:
# Timestamp('2012-10-12 00:00:00')

# %%
sell['Order Date'].sort_values(ascending = False)
# Out:
# 39602   2015-12-31
# 7908    2015-12-31
# 39873   2015-12-31
# 42870   2015-12-31
# 17379   2015-12-31
#            ...
# 31583   2012-01-01
# 31870   2012-01-01
# 25078   2012-01-01
# 43610   2012-01-01
# 22950   2012-01-01
# Name: Order Date, Length: 51290, dtype: datetime64[ns]

# %%
sell.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#              State        Country   Product ID     Sales  Quantity  Discount  \
# ...

# %%
sell.iloc[2]
# Out:
# Row ID                             25330
# Order ID          IN-2014-CR127307-41929
# Order Date           2014-10-17 00:00:00
# Ship Date            2014-10-18 00:00:00
# Ship Mode                    First Class
# Customer ID                    CR-127307
# Customer Name               Craig Reiter
# Segment                         Consumer
# Postal Code                          NaN
# City                            Brisbane
# State                         Queensland
# Country                        Australia
# Product ID                   TEC-PH-5356
# Sales                            5175.17
# Quantity                               9
# Discount                             0.1
# Profit                           919.971
# Shipping Cost                     915.49
# Order Priority                    Medium
# Name: 2, dtype: object

# %%
sell.iloc[20:]

sell.iloc[:4]
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
#
#              State        Country   Product ID     Sales  Quantity  Discount  \
# 0         Oklahoma  United States  TEC-PH-5816   221.980         2       0.0
# ...

# %%
sell.head(4)
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
#
#              State        Country   Product ID     Sales  Quantity  Discount  \
# 0         Oklahoma  United States  TEC-PH-5816   221.980         2       0.0
# ...

# %%
sell.sort_index(inplace = True)

# %%
sell.head()
# Out:
#           Row ID                  Order ID Order Date  Ship Date  \
# Segment
# Consumer   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13
# Consumer   11193   ES-2014-EB1411048-41780 2014-05-21 2014-05-25
# Consumer   20050  ES-2013-DD13570120-41605 2013-11-27 2013-12-01
# Consumer   31474  US-2013-JE15745140-41599 2013-11-21 2013-11-23
# Consumer   35145  CA-2015-JE15745140-42270 2015-09-23 2015-09-24
#
#                Ship Mode   Customer ID      Customer Name  Postal Code  \
# Segment
# Consumer     First Class  AB-100151402      Aaron Bergman      73120.0
# Consumer    Second Class    EB-1411048     Eugene Barchas          NaN
# Consumer  Standard Class   DD-13570120  Dorothy Dickinson          NaN
# Consumer    Second Class  JE-157451406         Joel Eaton      43055.0
# Consumer     First Class  JE-157451408         Joel Eaton      72701.0
#
#                    City             State        Country   Product ID  \
# Segment
# ...

# %%
sell.loc['Consumer',['Sales','Profit']]
# Out:
#             Sales    Profit
# Segment
# Consumer  221.980   62.1544
# Consumer   39.780   18.2700
# Consumer  179.460   71.6400
# Consumer  396.802  -11.3372
# Consumer  691.960  318.3016
# ...           ...       ...
# Consumer  883.920 -110.4900
# Consumer   41.958   10.6380
# Consumer   54.960   19.2300
# Consumer   87.600   27.1200
# Consumer  262.764  102.1440
#
# [26518 rows x 2 columns]

# %%
#sell.set_index('City',inplace = True)
sell.sort_index(inplace = True)

# %%
sell.loc[['Aachen','eMbalenhle']]
# Out:
#             Row ID                 Order ID Order Date  Ship Date  \
# City
# Aachen       11602  ES-2014-JE1571548-41710 2014-03-12 2014-03-16
# Aachen       17543  ES-2013-MA1799548-41394 2013-04-30 2013-05-06
# Aachen       18871  ES-2013-MO1750048-41588 2013-11-10 2013-11-14
# Aachen       19017  ES-2013-VP2176048-41629 2013-12-21 2013-12-21
# Aachen       18867  ES-2013-MO1750048-41588 2013-11-10 2013-11-14
# Aachen       12623  ES-2014-RC1982548-41965 2014-11-22 2014-11-28
# Aachen       18868  ES-2013-MO1750048-41588 2013-11-10 2013-11-14
# Aachen       14866  ES-2013-TS2165548-41591 2013-11-13 2013-11-14
# Aachen       12624  ES-2014-RC1982548-41965 2014-11-22 2014-11-28
# Aachen       18869  ES-2013-MO1750048-41588 2013-11-10 2013-11-14
# Aachen       17583  ES-2012-TB2152048-41195 2012-10-13 2012-10-18
# Aachen       14865  ES-2013-TS2165548-41591 2013-11-13 2013-11-14
# Aachen       14047  ES-2014-GZ1454548-41702 2014-03-04 2014-03-08
# ...

# %%
sell.iloc[:2]
# Out:
#         Row ID                 Order ID Order Date  Ship Date       Ship Mode  \
# City
# Aachen   11602  ES-2014-JE1571548-41710 2014-03-12 2014-03-16  Standard Class
# Aachen   17543  ES-2013-MA1799548-41394 2013-04-30 2013-05-06  Standard Class
#
#        Customer ID    Customer Name  Postal Code                   State  \
# City
# Aachen  JE-1571548       Joe Elijah          NaN  North Rhine-Westphalia
# Aachen  MA-1799548  Michelle Arnett          NaN  North Rhine-Westphalia
#
#         Country   Product ID   Sales  Quantity  Discount  Profit  \
# City
# Aachen  Germany  OFF-BI-6402   11.82         2       0.0    1.02
# Aachen  Germany  OFF-BI-4815  101.76         2       0.0   46.80
#
#         Shipping Cost Order Priority
# City
# Aachen           1.46           High
# Aachen           8.42         Medium

# %%
sell.head(2)
# Out:
#         Row ID                 Order ID Order Date  Ship Date       Ship Mode  \
# City
# Aachen   11602  ES-2014-JE1571548-41710 2014-03-12 2014-03-16  Standard Class
# Aachen   17543  ES-2013-MA1799548-41394 2013-04-30 2013-05-06  Standard Class
#
#        Customer ID    Customer Name  Postal Code                   State  \
# City
# Aachen  JE-1571548       Joe Elijah          NaN  North Rhine-Westphalia
# Aachen  MA-1799548  Michelle Arnett          NaN  North Rhine-Westphalia
#
#         Country   Product ID   Sales  Quantity  Discount  Profit  \
# City
# Aachen  Germany  OFF-BI-6402   11.82         2       0.0    1.02
# Aachen  Germany  OFF-BI-4815  101.76         2       0.0   46.80
#
#         Shipping Cost Order Priority
# City
# Aachen           1.46           High
# Aachen           8.42         Medium

# %%
#sell.iloc[[1,2]]
sell.iloc[:2]
# Out:
#         Row ID                 Order ID Order Date  Ship Date       Ship Mode  \
# City
# Aachen   11602  ES-2014-JE1571548-41710 2014-03-12 2014-03-16  Standard Class
# Aachen   17543  ES-2013-MA1799548-41394 2013-04-30 2013-05-06  Standard Class
#
#        Customer ID    Customer Name  Postal Code                   State  \
# City
# Aachen  JE-1571548       Joe Elijah          NaN  North Rhine-Westphalia
# Aachen  MA-1799548  Michelle Arnett          NaN  North Rhine-Westphalia
#
#         Country   Product ID   Sales  Quantity  Discount  Profit  \
# City
# Aachen  Germany  OFF-BI-6402   11.82         2       0.0    1.02
# Aachen  Germany  OFF-BI-4815  101.76         2       0.0   46.80
#
#         Shipping Cost Order Priority
# City
# Aachen           1.46           High
# Aachen           8.42         Medium

# %%
sell.iloc[1:5]
# Out:
#         Row ID                 Order ID Order Date  Ship Date       Ship Mode  \
# City
# Aachen   17543  ES-2013-MA1799548-41394 2013-04-30 2013-05-06  Standard Class
# Aachen   18871  ES-2013-MO1750048-41588 2013-11-10 2013-11-14  Standard Class
# Aachen   19017  ES-2013-VP2176048-41629 2013-12-21 2013-12-21        Same Day
# Aachen   18867  ES-2013-MO1750048-41588 2013-11-10 2013-11-14  Standard Class
#
#        Customer ID     Customer Name  Postal Code                   State  \
# City
# Aachen  MA-1799548   Michelle Arnett          NaN  North Rhine-Westphalia
# Aachen  MO-1750048     Mary O'Rourke          NaN  North Rhine-Westphalia
# Aachen  VP-2176048  Victoria Pisteka          NaN  North Rhine-Westphalia
# Aachen  MO-1750048     Mary O'Rourke          NaN  North Rhine-Westphalia
#
#         Country   Product ID    Sales  Quantity  Discount  Profit  \
# City
# Aachen  Germany  OFF-BI-4815  101.760         2       0.0  46.800
# ...

# %%
sell.iloc[[1,2,3]]
# Out:
#         Row ID                 Order ID Order Date  Ship Date       Ship Mode  \
# City
# Aachen   17543  ES-2013-MA1799548-41394 2013-04-30 2013-05-06  Standard Class
# Aachen   18871  ES-2013-MO1750048-41588 2013-11-10 2013-11-14  Standard Class
# Aachen   19017  ES-2013-VP2176048-41629 2013-12-21 2013-12-21        Same Day
#
#        Customer ID     Customer Name  Postal Code                   State  \
# City
# Aachen  MA-1799548   Michelle Arnett          NaN  North Rhine-Westphalia
# Aachen  MO-1750048     Mary O'Rourke          NaN  North Rhine-Westphalia
# Aachen  VP-2176048  Victoria Pisteka          NaN  North Rhine-Westphalia
#
#         Country   Product ID    Sales  Quantity  Discount  Profit  \
# City
# Aachen  Germany  OFF-BI-4815  101.760         2       0.0  46.800
# Aachen  Germany  OFF-AR-3528  170.460         3       0.0  25.560
# Aachen  Germany  FUR-BO-4845  521.856         4       0.1  81.096
#
#         Shipping Cost Order Priority
# City
# ...

# %%
sell.head()
# Out:
#         Row ID                 Order ID Order Date  Ship Date       Ship Mode  \
# City
# Aachen   11602  ES-2014-JE1571548-41710 2014-03-12 2014-03-16  Standard Class
# Aachen   17543  ES-2013-MA1799548-41394 2013-04-30 2013-05-06  Standard Class
# Aachen   18871  ES-2013-MO1750048-41588 2013-11-10 2013-11-14  Standard Class
# Aachen   19017  ES-2013-VP2176048-41629 2013-12-21 2013-12-21        Same Day
# Aachen   18867  ES-2013-MO1750048-41588 2013-11-10 2013-11-14  Standard Class
#
#        Customer ID     Customer Name  Postal Code                   State  \
# City
# Aachen  JE-1571548        Joe Elijah          NaN  North Rhine-Westphalia
# Aachen  MA-1799548   Michelle Arnett          NaN  North Rhine-Westphalia
# Aachen  MO-1750048     Mary O'Rourke          NaN  North Rhine-Westphalia
# Aachen  VP-2176048  Victoria Pisteka          NaN  North Rhine-Westphalia
# Aachen  MO-1750048     Mary O'Rourke          NaN  North Rhine-Westphalia
#
# ...

# %%
sell.loc['Aachen':,['Ship Date','Order Date']]
# Out:
#                        Ship Date Order Date
# City
# Aachen                2014-03-16 2014-03-12
# Aachen                2013-05-06 2013-04-30
# Aachen                2013-11-14 2013-11-10
# Aachen                2013-12-21 2013-12-21
# Aachen                2013-11-14 2013-11-10
# ...                          ...        ...
# eMbalenhle            2012-08-22 2012-08-19
# Águas Lindas de Goiás 2015-03-12 2015-03-07
# Águas Lindas de Goiás 2015-03-18 2015-03-13
# Águas Lindas de Goiás 2015-03-12 2015-03-07
# Águas Lindas de Goiás 2014-12-21 2014-12-20
#
# [51290 rows x 2 columns]
